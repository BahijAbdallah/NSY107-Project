# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/remaining_behavior_ext.csv")
df.head()
# Out:
#    Unnamed: 0                                   _id  \
# 0           0  024aae60-1a81-3f37-bbe6-3f832c919706
# 1           1  028d67dd-c6d0-329f-a20e-78db9eab7a55
# 2           2  02d12bf9-5fe2-3d0c-b233-30e02224b686
# 3           3  0b3aee1e-dc3b-3728-bc55-f57a23446b3d
# 4           4  0dbfffb4-3ed4-3cb2-904d-c348501a996e
#
#    inter_api_access_duration(sec)  api_access_uniqueness  \
# 0                        7.010387               0.419355
# 1                       51.419393               0.252336
# 2                       25.860775               0.275000
# 3                        0.205909               0.818182
# 4                        0.122125               0.812500
#
#    sequence_length(count)  vsession_duration(min)  ip_type behavior  \
# 0                    31.0                   13040  default  outlier
# 1                   107.0                  330113  default  outlier
# 2                    40.0                   62066  default  outlier
# 3                    11.0                     136  default  outlier
# 4                    16.0                     118  default  outlier
#
#   behavior_type  num_sessions  num_users  num_unique_apis source
# 0       outlier           1.0        1.0             13.0      E
# 1       outlier           1.0        1.0             27.0      E
# 2       outlier           1.0        1.0             11.0      E
# 3       outlier           1.0        1.0              9.0      E
# 4       outlier           1.0        1.0             13.0      E

# %%
df.shape
# Out:
# (34423, 13)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', '_id', 'inter_api_access_duration(sec)',
#        'api_access_uniqueness', 'sequence_length(count)',
#        'vsession_duration(min)', 'ip_type', 'behavior', 'behavior_type',
#        'num_sessions', 'num_users', 'num_unique_apis', 'source'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 34423 entries, 0 to 34422
# Data columns (total 13 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unnamed: 0                      34423 non-null  int64
#  1   _id                             34423 non-null  str
#  2   inter_api_access_duration(sec)  34422 non-null  float64
#  3   api_access_uniqueness           34422 non-null  float64
#  4   sequence_length(count)          34423 non-null  float64
#  5   vsession_duration(min)          34423 non-null  int64
#  6   ip_type                         34423 non-null  str
#  7   behavior                        34423 non-null  str
#  8   behavior_type                   34423 non-null  str
#  9   num_sessions                    34423 non-null  float64
#  10  num_users                       34423 non-null  float64
#  11  num_unique_apis                 34423 non-null  float64
#  12  source                          34423 non-null  str
# dtypes: float64(6), int64(2), str(5)
# memory usage: 3.4 MB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                        0
# _id                               0
# inter_api_access_duration(sec)    1
# api_access_uniqueness             1
# sequence_length(count)            0
# vsession_duration(min)            0
# ip_type                           0
# behavior                          0
# behavior_type                     0
# num_sessions                      0
# num_users                         0
# num_unique_apis                   0
# source                            0
# dtype: int64

# %%
df.describe()
# Out:
#          Unnamed: 0  inter_api_access_duration(sec)  api_access_uniqueness  \
# count  34423.000000                    34422.000000           34422.000000
# mean   17211.000000                       20.548672               0.444437
# std     9937.208495                       77.845323               0.302303
# min        0.000000                        0.000000               0.000714
# 25%     8605.500000                        0.381705               0.190476
# 50%    17211.000000                        2.205273               0.384615
# 75%    25816.500000                        9.495604               0.666667
# max    34422.000000                     2333.627333               1.000000
#
#        sequence_length(count)  vsession_duration(min)  num_sessions  \
# count            34423.000000            3.442300e+04  34423.000000
# mean                65.140736            2.960553e+04      9.880022
# std                150.605273            7.987217e+04     65.043625
# min                  0.000000            0.000000e+00      1.000000
# 25%                  6.666667            5.430000e+02      1.000000
# 50%                 15.000000            5.972000e+03      1.000000
# 75%                 58.000000            2.505650e+04      3.000000
# max               2800.000000            2.787530e+06   1462.000000
#
#           num_users  num_unique_apis
# count  34423.000000     34423.000000
# mean       3.615432        15.491851
# std       10.520912        15.356068
# min        1.000000         0.000000
# 25%        1.000000         5.000000
# 50%        1.000000        10.000000
# 75%        2.000000        21.000000
# max      219.000000       178.000000

# %%
df["behavior"].value_counts()
# Out:
# behavior
# outlier                                                                    24146
# Normal                                                                      8946
# Googlebot/2.1                                                                 95
# BingPreview/1.0b                                                              94
# BingPreview/1.0b;bingbot/2.0                                                  93
#                                                                            ...
# AdsBot-Google;Chrome;Chrome Mobile;Firefox;Mobile Firefox;Mobile Safari        1
# SQL Injection                                                                  1
# AdsBot-Google;Apple Mail;Chrome Mobile;Mobile Safari;Safari                    1
# AdsBot-Google;Android browser;Chrome;Chrome Mobile;Mobile Safari;Silk          1
# Chrome;Chrome Mobile;Googlebot/2.1;Mobile Safari                               1
# Name: count, Length: 75, dtype: int64

# %%
df["behavior_type"].value_counts()
# Out:
# behavior_type
# outlier    24146
# normal      8946
# bot         1309
# attack        22
# Name: count, dtype: int64

# %%
df["behavior_type"].value_counts().plot(kind="bar")
plt.title("Behavior Distribution")
plt.xlabel("Behavior_Type")
plt.ylabel("Count")
plt.show()

# %%
df.describe()
# Out:
#          Unnamed: 0  inter_api_access_duration(sec)  api_access_uniqueness  \
# count  34423.000000                    34422.000000           34422.000000
# mean   17211.000000                       20.548672               0.444437
# std     9937.208495                       77.845323               0.302303
# min        0.000000                        0.000000               0.000714
# 25%     8605.500000                        0.381705               0.190476
# 50%    17211.000000                        2.205273               0.384615
# 75%    25816.500000                        9.495604               0.666667
# max    34422.000000                     2333.627333               1.000000
#
#        sequence_length(count)  vsession_duration(min)  num_sessions  \
# count            34423.000000            3.442300e+04  34423.000000
# mean                65.140736            2.960553e+04      9.880022
# std                150.605273            7.987217e+04     65.043625
# min                  0.000000            0.000000e+00      1.000000
# 25%                  6.666667            5.430000e+02      1.000000
# 50%                 15.000000            5.972000e+03      1.000000
# 75%                 58.000000            2.505650e+04      3.000000
# max               2800.000000            2.787530e+06   1462.000000
#
#           num_users  num_unique_apis
# count  34423.000000     34423.000000
# mean       3.615432        15.491851
# std       10.520912        15.356068
# min        1.000000         0.000000
# 25%        1.000000         5.000000
# 50%        1.000000        10.000000
# 75%        2.000000        21.000000
# max      219.000000       178.000000

# %%
df.columns
# Out:
# Index(['Unnamed: 0', '_id', 'inter_api_access_duration(sec)',
#        'api_access_uniqueness', 'sequence_length(count)',
#        'vsession_duration(min)', 'ip_type', 'behavior', 'behavior_type',
#        'num_sessions', 'num_users', 'num_unique_apis', 'source'],
#       dtype='str')
